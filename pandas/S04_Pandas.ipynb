# %% [markdown]
# Dataset link : https://eforexcel.com/wp/downloads-18-sample-csv-files-data-sets-for-testing-sales/
#
# github link : https://github.com/guipsamora/pandas_exercises/blob/master/02_Filtering_%26_Sorting/Chipotle/Exercises_with_solutions.ipynb

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
#to get present working directory

# %%
pwd
# Out:
# 'C:\\Users\\Akash\\Python\\00 Python_Master\\02_Pandas\\S01_Pandas'

# %%
#to change present working directory

# %%
cd D:\\Akash Personal
# Out:
# D:\Akash Personal

# %%
sales=pd.read_excel(r"C:\Users\Akash\Python\00 Python_Master\02_Pandas\S01_Pandas\100 Sales Records.xlsx")
sales.head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27     159.42     2533654.00
# 1        Online              C 2012-09-15     117.11      576782.80
# 2       Offline              L 2014-08-05     524.96     1158502.59
# 3        Online              C 2014-05-07       6.92       75591.66
# 4       Offline              L 2013-06-02     524.96     3296425.02
#
#    Total_Profit
# 0     951410.50
# 1     248406.36
# 2     224598.75
# 3      19525.82
# ...

# %% [markdown]
# # What is the number of observations in the dataset?

# %%
sales.shape
# Out:
# (100, 10)

# %%
sales.shape[0]
# Out:
# 100

# %%
sales.shape[1]
# Out:
# 10

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item_Type       100 non-null    object
#  3   Sales_Channel   100 non-null    object
#  4   Order_Priority  100 non-null    object
#  5   Ship_Date       100 non-null    datetime64[ns]
#  6   Unit_Cost       100 non-null    float64
#  7   Total_Revenue   100 non-null    float64
#  8   Total_Profit    100 non-null    float64
#  9   region_country  100 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(6)
# memory usage: 7.9+ KB

# %% [markdown]
# # Print the name of all the columns.

# %%
#Names of all columns in dataset
sales.columns
# Out:
# Index(['Region', 'Country', 'Item_Type', 'Sales_Channel', 'Order_Priority',
#        'Ship_Date', 'Unit_Cost', 'Total_Revenue', 'Total_Profit'],
#       dtype='object')

# %% [markdown]
# # How is the dataset indexed?

# %%
sales.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %% [markdown]
# # Which was the most-profitable item category?

# %%
c = sales.groupby('Item_Type')
c = c.sum()
c = c.sort_values(['Total_Profit'], ascending=False)
c.head(5)
# Out:
#                  Unit_Cost  Total_Revenue  Total_Profit
# Item_Type
# Cosmetics          3423.29    36601509.60   14556048.66
# Household          4522.86    29889712.29    7412605.71
# Office Supplies    6299.52    30585380.07    5929583.75
# Clothes             465.92     7787292.80    5233334.40
# Baby Food          1115.94    10350327.60    3886643.70

# %% [markdown]
# # Which was the most-profitable region?

# %%
c = sales.groupby('Region')
c = c.sum()
c = c.sort_values(['Total_Profit'], ascending=False)
c.head(5)
# Out:
#                               Unit_Cost  Total_Revenue  Total_Profit
# Region
# Sub_Saharan Africa              6612.39    39672031.43   12183211.40
# Europe                          4909.66    33368932.11   11082938.63
# Asia                            2635.46    21347091.02    6113845.87
# Middle East and North Africa    1524.50    14052706.58    5761191.86
# Australia and Oceania           1702.19    14094265.13    4722160.03

# %% [markdown]
# # Which was the most-profitable country?

# %%
c = sales.groupby('Country')
c = c.sum()
c = c.sort_values(['Total_Profit'], ascending=False)
c.head(5)
# Out:
#           Unit_Cost  Total_Revenue  Total_Profit
# Country
# Djibouti     477.88     6052890.86    2425317.87
# Myanmar      538.38     6161257.90    1802771.70
# Pakistan     263.33     4324782.40    1719922.04
# Samoa        263.33     4220728.80    1678540.98
# Honduras     599.98     6336545.48    1609947.52

# %% [markdown]
# # Which was the most-profitable sales channel?

# %%
c = sales.groupby('Sales_Channel')
c = c.sum()
c = c.sort_values(['Total_Profit'], ascending=False)
c.head(5)
# Out:
#                Unit_Cost  Total_Revenue  Total_Profit
# Sales_Channel
# Offline         10841.15    79094809.20   24920726.67
# Online           8263.65    58253959.11   19247471.73

# %% [markdown]
# # Which was the most-profitable according to order_priority?

# %%
c = sales.groupby('Order_Priority')
c = c.sum()
c = c.sort_values(['Total_Profit'], ascending=False)
c.head(5)
# Out:
#                 Unit_Cost  Total_Revenue  Total_Profit
# Order_Priority
# H                 5708.06    48749546.05   16891599.58
# L                 5689.05    36628127.46   10858727.86
# M                 4947.36    33116031.75    9669542.50
# C                 2760.33    18855063.05    6748328.46

# %% [markdown]
# # Create a lambda function and change the type of item cost to integer & then back to float.

# %%
format_change_to_int = lambda x: int(x)
sales.Unit_Cost = sales.Unit_Cost.apply(format_change_to_int)

# %%
#First 5 records of data
sales.head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27        159     2533654.00
# 1        Online              C 2012-09-15        117      576782.80
# 2       Offline              L 2014-08-05        524     1158502.59
# 3        Online              C 2014-05-07          6       75591.66
# 4       Offline              L 2013-06-02        524     3296425.02
#
#    Total_Profit                                 region_country
# ...

# %%
format_change_to_float = lambda x: float(x)
sales.Unit_Cost = sales.Unit_Cost.apply(format_change_to_float)

# %%
#First 5 records of data
sales.head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27      159.0     2533654.00
# 1        Online              C 2012-09-15      117.0      576782.80
# 2       Offline              L 2014-08-05      524.0     1158502.59
# 3        Online              C 2014-05-07        6.0       75591.66
# 4       Offline              L 2013-06-02      524.0     3296425.02
#
#    Total_Profit                                 region_country
# ...

# %%
sales.Unit_Cost.dtype
# Out:
# dtype('float64')

# %%
sales.groupby(by=['Country']).sum()['Total_Revenue']
# Out:
# Country
# Albania            247956.32
# Angola            2798046.49
# Australia         2489933.49
# Austria           1244708.40
# Azerbaijan        4478800.21
#                      ...
# The Gambia        5449517.95
# Turkmenistan      5822036.20
# Tuvalu            2533654.00
# United Kingdom     188452.14
# Zambia             623289.30
# Name: Total_Revenue, Length: 76, dtype: float64

# %% [markdown]
# # How many different items are sold?

# %%
sales.Item_Type.value_counts().count()
# Out:
# 12

# %%
sales.describe(include = "all")
# Out:
#                     Region     Country Item_Type Sales_Channel Order_Priority  \
# count                  100         100       100           100            100
# unique                   7          76        12             2              4
# top     Sub_Saharan Africa  The Gambia   Clothes       Offline              H
# freq                    36           4        13            50             30
# first                  NaN         NaN       NaN           NaN            NaN
# last                   NaN         NaN       NaN           NaN            NaN
# mean                   NaN         NaN       NaN           NaN            NaN
# std                    NaN         NaN       NaN           NaN            NaN
# min                    NaN         NaN       NaN           NaN            NaN
# 25%                    NaN         NaN       NaN           NaN            NaN
# 50%                    NaN         NaN       NaN           NaN            NaN
# ...

# %% [markdown]
# # Sort by the name of the item

# %%
sales.Item_Type.sort_values()
# Out:
# 0      Baby Food
# 21     Baby Food
# 20     Baby Food
# 87     Baby Food
# 61     Baby Food
#          ...
# 84    Vegetables
# 43    Vegetables
# 7     Vegetables
# 77    Vegetables
# 97    Vegetables
# Name: Item_Type, Length: 100, dtype: object

# %% [markdown]
# # Groupby

# %%
sales.groupby('Country').mean()
# Out:
#                 Unit_Cost  Total_Revenue   Total_Profit
# Country
# Albania              35.0   2.479563e+05  166635.360000
# Angola              502.0   2.798046e+06  693911.510000
# Australia           224.0   8.299778e+05  192201.706667
# Austria             263.0   1.244708e+06  495007.890000
# Azerbaijan          393.5   2.239400e+06  756463.415000
# ...                   ...            ...            ...
# The Gambia          285.5   1.362379e+06  346470.817500
# Turkmenistan        513.0   2.911018e+06  633629.200000
# Tuvalu              159.0   2.533654e+06  951410.500000
# United Kingdom      502.0   1.884521e+05   46735.860000
# Zambia               97.0   6.232893e+05  225246.900000
#
# [76 rows x 3 columns]

# %%
sales.groupby('Country').median()
# Out:
#                 Unit_Cost  Total_Revenue  Total_Profit
# Country
# Albania              35.0     247956.320    166635.360
# Angola              502.0    2798046.490    693911.510
# Australia           117.0     445508.050    147031.740
# Austria             263.0    1244708.400    495007.890
# Azerbaijan          393.5    2239400.105    756463.415
# ...                   ...            ...           ...
# The Gambia          261.5    1501450.710    332726.250
# Turkmenistan        513.0    2911018.100    633629.200
# Tuvalu              159.0    2533654.000    951410.500
# United Kingdom      502.0     188452.140     46735.860
# Zambia               97.0     623289.300    225246.900
#
# [76 rows x 3 columns]

# %%
sales.groupby('Country').max()
# Out:
#                                       Region        Item_Type Sales_Channel  \
# Country
# Albania                               Europe          Clothes        Online
# Angola                    Sub_Saharan Africa        Household       Offline
# Australia              Australia and Oceania  Office Supplies        Online
# Austria                               Europe        Cosmetics       Offline
# Azerbaijan      Middle East and North Africa  Office Supplies        Online
# ...                                      ...              ...           ...
# The Gambia                Sub_Saharan Africa             Meat        Online
# Turkmenistan                            Asia  Office Supplies        Online
# Tuvalu                 Australia and Oceania        Baby Food       Offline
# United Kingdom                        Europe        Household        Online
# Zambia                    Sub_Saharan Africa           Snacks        Online
#
# ...

# %%
sales.groupby('Region').Total_Profit.agg(['mean', 'min', 'max'])
# Out:
#                                             mean        min         max
# Region
# Asia                               555804.170000    7828.12  1367272.50
# Australia and Oceania              429287.275455    5270.67  1678540.98
# Central America and the Caribbean  406701.121429  122686.50  1487261.02
# Europe                             503769.937727    6841.38  1541705.29
# Middle East and North Africa       576119.186000    1258.02  1719922.04
# North America                      485980.920000  144521.02  1152486.42
# Sub_Saharan Africa                 338422.538889   14031.02  1254472.05

# %% [markdown]
# # Slicing & Dicing

# %%
#select a single column(Selecting data using Labels (Column Headings))
sales['Region'].head()
# Out:
# 0                Australia and Oceania
# 1    Central America and the Caribbean
# 2                               Europe
# 3                   Sub_Saharan Africa
# 4                   Sub_Saharan Africa
# Name: Region, dtype: object

# %%
#Method 2: use the column name as an 'attribute'; gives the same output
sales.Region.head()
# Out:
# 0                Australia and Oceania
# 1    Central America and the Caribbean
# 2                               Europe
# 3                   Sub_Saharan Africa
# 4                   Sub_Saharan Africa
# Name: Region, dtype: object

# %%
#pass a list of column(select multiple columns)
sales[['Region','Total_Profit']].head()
# Out:
#                               Region  Total_Profit
# 0              Australia and Oceania     951410.50
# 1  Central America and the Caribbean     248406.36
# 2                             Europe     224598.75
# 3                 Sub_Saharan Africa      19525.82
# 4                 Sub_Saharan Africa     639077.50

# %%
#what if you flip the order
sales[['Total_Profit','Region']].head()
# Out:
#    Total_Profit                             Region
# 0     951410.50              Australia and Oceania
# 1     248406.36  Central America and the Caribbean
# 2     224598.75                             Europe
# 3      19525.82                 Sub_Saharan Africa
# 4     639077.50                 Sub_Saharan Africa

# %%
#create an object that only contain Region column
Region_data=sales['Region']
Region_data.head()
# Out:
# 0                Australia and Oceania
# 1    Central America and the Caribbean
# 2                               Europe
# 3                   Sub_Saharan Africa
# 4                   Sub_Saharan Africa
# Name: Region, dtype: object

# %%
#Creating a new column-new
sales['region_country']=sales['Region']+sales['Country']
sales.head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27     159.42     2533654.00
# 1        Online              C 2012-09-15     117.11      576782.80
# 2       Offline              L 2014-08-05     524.96     1158502.59
# 3        Online              C 2014-05-07       6.92       75591.66
# 4       Offline              L 2013-06-02     524.96     3296425.02
#
#    Total_Profit                            region_country
# ...

# %%
#Creating a new column-new
sales['region_country']=sales['Region']+" AND "+sales['Country']
sales.head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27     159.42     2533654.00
# 1        Online              C 2012-09-15     117.11      576782.80
# 2       Offline              L 2014-08-05     524.96     1158502.59
# 3        Online              C 2014-05-07       6.92       75591.66
# 4       Offline              L 2013-06-02     524.96     3296425.02
#
#    Total_Profit                                 region_country
# ...

# %%
#Slicing Subsets of Rows in Python
#select first 3 rows
sales[0:3]
# Out:
#                               Region  Country        Item_Type Sales_Channel  \
# 0              Australia and Oceania   Tuvalu        Baby Food       Offline
# 1  Central America and the Caribbean  Grenada           Cereal        Online
# 2                             Europe   Russia  Office Supplies       Offline
#
#   Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  \
# 0              H 2010-06-27      159.0     2533654.00     951410.50
# 1              C 2012-09-15      117.0      576782.80     248406.36
# 2              L 2014-08-05      524.0     1158502.59     224598.75
#
#                                   region_country
# 0               Australia and Oceania AND Tuvalu
# 1  Central America and the Caribbean AND Grenada
# 2                              Europe AND Russia

# %%
#select first 5 rows
sales[:5]
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27      159.0     2533654.00
# 1        Online              C 2012-09-15      117.0      576782.80
# 2       Offline              L 2014-08-05      524.0     1158502.59
# 3        Online              C 2014-05-07        6.0       75591.66
# 4       Offline              L 2013-06-02      524.0     3296425.02
#
#    Total_Profit                                 region_country
# ...

# %%
# Select the last row in the dataset
sales[-1:]
# Out:
#                 Region     Country  Item_Type Sales_Channel Order_Priority  \
# 99  Sub_Saharan Africa  Mozambique  Household       Offline              L
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  \
# 99 2012-02-15      502.0     3586605.09     889472.91
#
#                        region_country
# 99  Sub_Saharan Africa AND Mozambique

# %% [markdown]
# # LOC

# %%
# Select all columns for rows of index values 0 and 10
sales.loc[[0, 10], :]
# Out:
#                    Region     Country   Item_Type Sales_Channel  \
# 0   Australia and Oceania      Tuvalu   Baby Food       Offline
# 10                   Asia  Kyrgyzstan  Vegetables        Online
#
#    Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  \
# 0               H 2010-06-27      159.0     2533654.00     951410.50
# 10              H 2011-12-07       90.0       19103.44       7828.12
#
#                       region_country
# 0   Australia and Oceania AND Tuvalu
# 10               Asia AND Kyrgyzstan

# %%
# Select all columns for rows of index values 0 and 10
sales.loc[0:10, :]
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# 5               Australia and Oceania        Solomon Islands        Baby Food
# 6                  Sub_Saharan Africa                 Angola        Household
# 7                  Sub_Saharan Africa           Burkina Faso       Vegetables
# 8                  Sub_Saharan Africa  Republic of the Congo    Personal Care
# 9                  Sub_Saharan Africa                Senegal           Cereal
# 10                               Asia             Kyrgyzstan       Vegetables
#
# ...

# %%
# Select all columns for rows of index values 0 and 10
sales.loc[0:10,:]
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# 5               Australia and Oceania        Solomon Islands        Baby Food
# 6                  Sub_Saharan Africa                 Angola        Household
# 7                  Sub_Saharan Africa           Burkina Faso       Vegetables
# 8                  Sub_Saharan Africa  Republic of the Congo    Personal Care
# 9                  Sub_Saharan Africa                Senegal           Cereal
# 10                               Asia             Kyrgyzstan       Vegetables
#
# ...

# %%
sales.loc[0:10,"Region":"Order_Priority"]
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# 5               Australia and Oceania        Solomon Islands        Baby Food
# 6                  Sub_Saharan Africa                 Angola        Household
# 7                  Sub_Saharan Africa           Burkina Faso       Vegetables
# 8                  Sub_Saharan Africa  Republic of the Congo    Personal Care
# 9                  Sub_Saharan Africa                Senegal           Cereal
# 10                               Asia             Kyrgyzstan       Vegetables
#
#    Sales_Channel Order_Priority
# ...

# %%
sales.loc[0:5, ['Region', 'Country', 'Item_Type']]
# Out:
#                               Region                Country        Item_Type
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
# 5              Australia and Oceania        Solomon Islands        Baby Food

# %%
sales.loc[[0, 10, 25],:]
# Out:
#                    Region     Country   Item_Type Sales_Channel  \
# 0   Australia and Oceania      Tuvalu   Baby Food       Offline
# 10                   Asia  Kyrgyzstan  Vegetables        Online
# 25                 Europe      France   Cosmetics        Online
#
#    Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  \
# 0               H 2010-06-27      159.0     2533654.00     951410.50
# 10              H 2011-12-07       90.0       19103.44       7828.12
# 25              H 2017-05-06      263.0      793518.00     315574.05
#
#                       region_country
# 0   Australia and Oceania AND Tuvalu
# 10               Asia AND Kyrgyzstan
# 25                 Europe AND France

# %%
sales.loc[[0,4],:]
# Out:
#                   Region Country        Item_Type Sales_Channel  \
# 0  Australia and Oceania  Tuvalu        Baby Food       Offline
# 4     Sub_Saharan Africa  Rwanda  Office Supplies       Offline
#
#   Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  \
# 0              H 2010-06-27      159.0     2533654.00      951410.5
# 4              L 2013-06-02      524.0     3296425.02      639077.5
#
#                      region_country
# 0  Australia and Oceania AND Tuvalu
# 4     Sub_Saharan Africa AND Rwanda

# %% [markdown]
# # ILOC

# %%
# Syntax for iloc indexing to finding a specific data element
#sales.iloc[row, column]

# %%
#value in 2nd row and 6th column
sales.iloc[2,6]
# Out:
# 524.0

# %%
#Slicing Subsets of Rows and Columns in Python
# To select a subset of rows and columns from our DataFrame, 
# we can use the iloc method. For example, we can select month, day and year 
#(columns 2, 3 and 4 if we start counting at 1), like this:
#iloc[row slicing,column slicing]

# %%
sales.iloc[0:10,0:5]
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
# 5              Australia and Oceania        Solomon Islands        Baby Food
# 6                 Sub_Saharan Africa                 Angola        Household
# 7                 Sub_Saharan Africa           Burkina Faso       Vegetables
# 8                 Sub_Saharan Africa  Republic of the Congo    Personal Care
# 9                 Sub_Saharan Africa                Senegal           Cereal
#
#   Sales_Channel Order_Priority
# 0       Offline              H
# 1        Online              C
# ...

# %%
sales.iloc[2:6,6:9]
# Out:
#    Unit_Cost  Total_Revenue  Total_Profit
# 2      524.0     1158502.59     224598.75
# 3        6.0       75591.66      19525.82
# 4      524.0     3296425.02     639077.50
# 5      159.0      759202.72     285087.64

# %% [markdown]
# # Subsetting & Filter

# %%
#Subsetting Data using Criteria
sales
sales[sales.Sales_Channel == "Offline"]
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 2                              Europe                 Russia  Office Supplies
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# 6                  Sub_Saharan Africa                 Angola        Household
# 8                  Sub_Saharan Africa  Republic of the Congo    Personal Care
# 11                 Sub_Saharan Africa             Cape Verde          Clothes
# 13  Central America and the Caribbean               Honduras        Household
# 14                               Asia               Mongolia    Personal Care
# 16                               Asia              Sri Lanka        Cosmetics
# 17                 Sub_Saharan Africa               Cameroon        Beverages
# 18                               Asia           Turkmenistan        Household
# ...

# %%
sales
sales[sales.Sales_Channel != "Offline"]
# Out:
#                                Region                           Country  \
# 1   Central America and the Caribbean                           Grenada
# 3                  Sub_Saharan Africa             Sao Tome and Principe
# 5               Australia and Oceania                   Solomon Islands
# 7                  Sub_Saharan Africa                      Burkina Faso
# 9                  Sub_Saharan Africa                           Senegal
# 10                               Asia                        Kyrgyzstan
# 12                               Asia                        Bangladesh
# 15                             Europe                          Bulgaria
# 19              Australia and Oceania                        East Timor
# 20                             Europe                            Norway
# 21                             Europe                          Portugal
# 22  Central America and the Caribbean                          Honduras
# ...

# %%
sales[(sales.Total_Profit >= 150000) & (sales.Total_Revenue >= 50000)].head()
# Out:
#                               Region          Country        Item_Type  \
# 0              Australia and Oceania           Tuvalu        Baby Food
# 1  Central America and the Caribbean          Grenada           Cereal
# 2                             Europe           Russia  Office Supplies
# 4                 Sub_Saharan Africa           Rwanda  Office Supplies
# 5              Australia and Oceania  Solomon Islands        Baby Food
#
#   Sales_Channel Order_Priority  Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H 2010-06-27      159.0     2533654.00
# 1        Online              C 2012-09-15      117.0      576782.80
# 2       Offline              L 2014-08-05      524.0     1158502.59
# 4       Offline              L 2013-06-02      524.0     3296425.02
# 5        Online              C 2015-02-21      159.0      759202.72
#
#    Total_Profit                                 region_country
# 0     951410.50               Australia and Oceania AND Tuvalu
# ...

# %% [markdown]
# # Descriptive Statistics

# %%
sales.mean()
# Out:
# Unit_Cost        1.903900e+02
# Total_Revenue    1.373488e+06
# Total_Profit     4.416820e+05
# dtype: float64

# %%
sales.median()
# Out:
# Unit_Cost           107.000
# Total_Revenue    752314.360
# Total_Profit     290767.995
# dtype: float64

# %%
sales.mode()
# Out:
#                 Region     Country  Item_Type Sales_Channel Order_Priority  \
# 0   Sub_Saharan Africa  The Gambia    Clothes       Offline              H
# 1                  NaN         NaN  Cosmetics        Online            NaN
# 2                  NaN         NaN        NaN           NaN            NaN
# 3                  NaN         NaN        NaN           NaN            NaN
# 4                  NaN         NaN        NaN           NaN            NaN
# ..                 ...         ...        ...           ...            ...
# 95                 NaN         NaN        NaN           NaN            NaN
# 96                 NaN         NaN        NaN           NaN            NaN
# 97                 NaN         NaN        NaN           NaN            NaN
# 98                 NaN         NaN        NaN           NaN            NaN
# 99                 NaN         NaN        NaN           NaN            NaN
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  \
# ...

# %%
sales.describe()
# Out:
#         Unit_Cost  Total_Revenue  Total_Profit
# count  100.000000   1.000000e+02  1.000000e+02
# mean   190.390000   1.373488e+06  4.416820e+05
# std    188.220046   1.460029e+06  4.385379e+05
# min      6.000000   4.870260e+03  1.258020e+03
# 25%     35.000000   2.687212e+05  1.214436e+05
# 50%    107.000000   7.523144e+05  2.907680e+05
# 75%    263.000000   2.212045e+06  6.358288e+05
# max    524.000000   5.997055e+06  1.719922e+06
